# %%
# Importing libraries
import pandas as pd

# Creating resume dataframe
df_col = pd.read_csv(r"D:\Precipitation\by_water_year\era5land_total_precipitation_1950_1951_(mm).csv", compression = "zip")
max_precipitations = pd.DataFrame(columns = ["year", "type_of_period", "duration"] + list(df_col.columns[2:]))

Y = range(1950, 2023) #1950-2023
T = ["no restriction", "9h-9h"]
H = [1,2,4,6,8,12,24,48,72,96,120]
i = -1
    
for year in Y:
    df_year = pd.read_csv(r"D:\Precipitation\by_water_year\era5land_total_precipitation_" + str(year) + "_" + str(year+1) + "_(mm).csv", compression = "zip")
    print("Water year " + str(year) + "_" + str(year+1) + " processed.")

    for type_of_period in T:
        
        for hours in H:
            i += 1
            df_roll = df_year.iloc[:, 2:].rolling(hours).sum()
            df_roll = pd.concat([df_year.iloc[0:(8761-hours),0], df_year.iloc[(hours-1):,1].reset_index(drop = True), df_roll.iloc[(hours-1):, :].reset_index(drop = True)], axis = 1)
            df_roll.columns = df_year.columns
            df_roll["ti"] = pd.to_datetime(df_roll["ti"], format = '%Y-%m-%d %H:%M:%S')
            df_roll["tf"] = pd.to_datetime(df_roll["tf"], format = '%Y-%m-%d %H:%M:%S')

            if type_of_period == "9h-9h":
                if hours < 24:
                    df_roll = df_roll[((df_roll["ti"].dt.hour < df_roll["tf"].dt.hour) & (df_roll["ti"].dt.hour >= 9)) | ((df_roll["ti"].dt.hour < df_roll["tf"].dt.hour) & (df_roll["tf"].dt.hour <= 9)) | ((df_roll["ti"].dt.hour > df_roll["tf"].dt.hour) & (df_roll["ti"].dt.hour >= 9) & (df_roll["tf"].dt.hour <= 9))]
                else:
                    df_roll = df_roll[(df_roll["ti"].dt.hour == 9) & (df_roll["tf"].dt.hour == 9)]
                
                
            content = [str(year) + "_" + str(year+1), type_of_period, str(hours) + "h"] + list(df_roll.iloc[:,2:].max())
            max_precipitations.loc[i, :] = content

max_precipitations.to_csv(r"D:\Precipitation\by_water_year\max_precipitations_(mm).csv", index = False)
max_precipitations
# Out:
# Water year 1950_1951 processed.
# Water year 1951_1952 processed.
# Water year 1952_1953 processed.
# Water year 1953_1954 processed.
# Water year 1954_1955 processed.
# Water year 1955_1956 processed.
# Water year 1956_1957 processed.
# Water year 1957_1958 processed.
# Water year 1958_1959 processed.
# Water year 1959_1960 processed.
# Water year 1960_1961 processed.
# Water year 1961_1962 processed.
# Water year 1962_1963 processed.
# Water year 1963_1964 processed.
# Water year 1964_1965 processed.
# Water year 1965_1966 processed.
# Water year 1966_1967 processed.
# Water year 1967_1968 processed.
# Water year 1968_1969 processed.
# Water year 1969_1970 processed.
# Water year 1970_1971 processed.
# Water year 1971_1972 processed.
# Water year 1972_1973 processed.
# Water year 1973_1974 processed.
# Water year 1974_1975 processed.
# Water year 1975_1976 processed.
# Water year 1976_1977 processed.
# Water year 1977_1978 processed.
# Water year 1978_1979 processed.
# Water year 1979_1980 processed.
# Water year 1980_1981 processed.
# Water year 1981_1982 processed.
# Water year 1982_1983 processed.
# Water year 1983_1984 processed.
# Water year 1984_1985 processed.
# Water year 1985_1986 processed.
# Water year 1986_1987 processed.
# Water year 1987_1988 processed.
# Water year 1988_1989 processed.
# Water year 1989_1990 processed.
# Water year 1990_1991 processed.
# Water year 1991_1992 processed.
# Water year 1992_1993 processed.
# Water year 1993_1994 processed.
# Water year 1994_1995 processed.
# Water year 1995_1996 processed.
# Water year 1996_1997 processed.
# Water year 1997_1998 processed.
# Water year 1998_1999 processed.
# Water year 1999_2000 processed.
